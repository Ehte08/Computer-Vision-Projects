# %%
import cv2 as cv
import pytesseract
from PIL import Image
import numpy as np

# %%
import pytesseract
from PIL import Image

img = Image.open("december.jpg")
text = pytesseract.image_to_string(img)
print(text)
# Out:
# 5.2.0
# DECEMBER
